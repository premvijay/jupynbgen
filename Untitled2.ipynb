# %%
import numpy

# %%
import yt
# Out:
# C:\Users\premv\anaconda3\lib\_collections_abc.py:666: MatplotlibDeprecationWarning: The global colormaps dictionary is no longer considered public API.
#   self[key]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3])
