# %%
import numpy as np

# %%
import yt

# %%
ds = yt.load('/scratch/cprem/download/TNG50-4/snaps/snap_099.0.hdf5')
# Out:
# yt : [INFO     ] 2021-04-14 00:25:16,587 Calculating time from 1.000e+00 to be 4.356e+17 seconds
# yt : [INFO     ] 2021-04-14 00:25:16,748 Parameters: current_time              = 4.355810528213311e+17 s
# yt : [INFO     ] 2021-04-14 00:25:16,750 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2021-04-14 00:25:16,751 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-04-14 00:25:16,752 Parameters: domain_right_edge         = [35000. 35000. 35000.]
# yt : [INFO     ] 2021-04-14 00:25:16,753 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2021-04-14 00:25:16,754 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2021-04-14 00:25:16,755 Parameters: omega_lambda              = 0.6911
# yt : [INFO     ] 2021-04-14 00:25:16,756 Parameters: omega_matter              = 0.3089
# yt : [INFO     ] 2021-04-14 00:25:16,756 Parameters: omega_radiation           = 0.0
# ...

# %%
ds.fields
# Out:
# yt : [INFO     ] 2021-04-14 00:25:26,109 Allocating for 5.852e+07 particles
# Loading particle index:  99%|█████████▉| 79/80 [00:19<00:00,  4.10it/s]
# ...

# %%
ds.index.__class__
# Out:
# yt.frontends.sph.data_structures.SPHParticleIndex

# %%
px1 = yt.SlicePlot(ds, 'z', ('gas', 'density'))
# Out:
# yt : [INFO     ] 2021-04-11 00:07:04,070 xlim = 0.000000 35000.000000
# yt : [INFO     ] 2021-04-11 00:07:04,071 ylim = 0.000000 35000.000000
# yt : [INFO     ] 2021-04-11 00:07:04,072 xlim = 0.000000 35000.000000
# yt : [INFO     ] 2021-04-11 00:07:04,073 ylim = 0.000000 35000.000000
# yt : [INFO     ] 2021-04-11 00:07:04,074 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800

# %%
px1.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
px2 = yt.SlicePlot(ds, 'x', ('gas', 'density'), origin='native', center=[ds.quan(12.5, 'Mpc'), ds.quan(36, 'Mpc'), ds.quan(25, 'Mpc')])
# Out:
# yt : [INFO     ] 2021-04-14 00:45:29,588 xlim = 10.165925 61.834075
# yt : [INFO     ] 2021-04-14 00:45:29,589 ylim = -0.834075 50.834075
# yt : [INFO     ] 2021-04-14 00:45:29,592 xlim = 6886.396688 41886.396688
# yt : [INFO     ] 2021-04-14 00:45:29,593 ylim = -565.002300 34434.997700
# yt : [INFO     ] 2021-04-14 00:45:29,595 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800

# %%
px2.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
px3 = yt.SlicePlot(ds, 'z', ('gas', 'density'), width=(5000,5000), origin='native', center=[ds.quan(10.8, 'Mpc'), ds.quan(36.3, 'Mpc'), ds.quan(31.5, 'Mpc')])
# Out:
# yt : [INFO     ] 2021-04-14 01:01:18,654 xlim = 7.109418 14.490582
# yt : [INFO     ] 2021-04-14 01:01:18,657 ylim = 32.609418 39.990582
# yt : [INFO     ] 2021-04-14 01:01:18,658 xlim = 4815.919006 9815.919006
# yt : [INFO     ] 2021-04-14 01:01:18,659 ylim = 22089.616661 27089.616661
# yt : [INFO     ] 2021-04-14 01:01:18,661 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800

# %%
px3.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
px4 = yt.SlicePlot(ds, 'x', ('gas', 'density'), width=(5000,5000), origin='native', center=[ds.quan(10.8, 'Mpc'), ds.quan(36.3, 'Mpc'), ds.quan(31.5, 'Mpc')])
# Out:
# yt : [INFO     ] 2021-04-14 01:01:59,553 xlim = 32.609418 39.990582
# yt : [INFO     ] 2021-04-14 01:01:59,555 ylim = 27.809418 35.190582
# yt : [INFO     ] 2021-04-14 01:01:59,557 xlim = 22089.616661 27089.616661
# yt : [INFO     ] 2021-04-14 01:01:59,558 ylim = 18838.097102 23838.097102
# yt : [INFO     ] 2021-04-14 01:01:59,560 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800

# %%
px4.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ds.index

# %%
px5 = yt.SlicePlot(ds, 'z', ('deposit', 'all_density'), width=(5000,5000), origin='native', center=[ds.quan(10.8, 'Mpc'), ds.quan(36.3, 'Mpc'), ds.quan(31.5, 'Mpc')])
# Out:
# ---------------------------------------------------------------------------
# NeedsGridType                             Traceback (most recent call last)
# ~/Downloads/yt/yt/data_objects/data_containers.py in _generate_fluid_field(self, field)
#     303         try:
# --> 304             finfo.check_available(gen_obj)
#     305         except NeedsGridType as ngt_exception:
#
# ~/Downloads/yt/yt/fields/derived_field.py in check_available(self, data)
#     243         for validator in self.validators:
# --> 244             validator(data)
#     245         # If we don't get an exception, we're good to go
#
# ~/Downloads/yt/yt/fields/derived_field.py in __call__(self, data)
#     560         if not getattr(data, "_spatial", False):
# --> 561             raise NeedsGridType(self.ghost_zones, self.fields)
#     562         if self.ghost_zones <= data._num_ghost_zones:
#
# NeedsGridType: fields None require 0 ghost zones.
#
# ...

# %%
px5.show()

# %%
px2.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ds2 = yt.load('/scratch/cprem/sims/DM-Zoom-Aq-C-5/snaps/snapdir_005/snapshot_005.0.hdf5')
# Out:
# yt : [INFO     ] 2021-04-14 11:32:25,874 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2021-04-14 11:32:25,876 Assuming length units are in kpc (physical)
# yt : [INFO     ] 2021-04-14 11:32:25,996 Parameters: current_time              = 0.18422877390319162
# yt : [INFO     ] 2021-04-14 11:32:25,997 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2021-04-14 11:32:25,998 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-04-14 11:32:25,999 Parameters: domain_right_edge         = [100. 100. 100.]
# yt : [INFO     ] 2021-04-14 11:32:26,000 Parameters: cosmological_simulation   = 0

# %%
ds2.fields
# Out:
# yt : [INFO     ] 2021-04-14 11:32:26,103 Allocating for 3.665e+06 particles
# Loading particle index:  94%|█████████▍| 15/16 [00:00<00:00, 10837.99it/s]
# ...

# %%
ds2.index

# %%
# px3 = yt.SlicePlot(ds, 'z', ('gas', 'density'), width=(10000,10000), center=[ds.quan(5.51575, 'Mpc'), ds.quan(9.82932, 'Mpc'), ds.quan(7.89961, 'Mpc')])

# %%
# px3.show()

# %%
px7 = yt.SlicePlot(ds2, 'z', ('deposit', 'PartType1_density'))
# Out:
# ---------------------------------------------------------------------------
# NeedsGridType                             Traceback (most recent call last)
# ~/Downloads/yt/yt/data_objects/data_containers.py in _generate_fluid_field(self, field)
#     303         try:
# --> 304             finfo.check_available(gen_obj)
#     305         except NeedsGridType as ngt_exception:
#
# ~/Downloads/yt/yt/fields/derived_field.py in check_available(self, data)
#     243         for validator in self.validators:
# --> 244             validator(data)
#     245         # If we don't get an exception, we're good to go
#
# ~/Downloads/yt/yt/fields/derived_field.py in __call__(self, data)
#     560         if not getattr(data, "_spatial", False):
# --> 561             raise NeedsGridType(self.ghost_zones, self.fields)
#     562         if self.ghost_zones <= data._num_ghost_zones:
#
# NeedsGridType: fields None require 0 ghost zones.
#
# ...

# %%
px7.show()

# %%
ad2 = ds2.all_data()

# %%
ad2
